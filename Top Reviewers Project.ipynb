# %% [markdown]
# # In this example, we are attempting to set up a dataframe, to be used as a Tableau data source, # to compare a fictitious entertainment website's internal reviewers' ratings--for shows/series-- against the average audience ratings for those very same shows/series. #This analysis will be using RottenTomatoes' average audience scores for said shows/series' audience average ratings. The end Result of the analysis will be to find the reviewers that have the most show specific ratings that are 5% or less away from what the RottenTomatoes' average audience rating for those same show/series. The Final Tableau Dashboard will be shared via email/link.

# %%
# Calling all my needed libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mysql
import mysql.connector 
import os
# %matplotlib inline

# %%
#List of all the series being reviewed.
series = ["Archer","Arrested Development","Bob's Burgers","Bojack Horseman",
          "Breaking Bad","Curb Your Enthusiasm",
         "Fargo", "Freaks and Geeks",
         "General Hospital","Halt and Catch Fire",
         "Seinfeld","Stranger Things"]

# %%
# The series' average audience ratings into a dictionary format.
tomatoscore={"Archer":85,"Arrested Development":85,"Bob's Burgers":88,"Bojack Horseman":96,
            "Breaking Bad":97,"Curb Your Enthusiasm":90,"Fargo":85,"Freaks and Geeks":96,
           "General Hospital":0,"Halt and Catch Fire":0,
            "Seinfeld":92,"Stranger Things":90}

# %%
# Creating a dataframe from the average audience ratings' dictionary and series' name list.
#This final dataframe will be called audience average rating or "tom_df."
tom_df = pd.DataFrame.from_dict(tomatoscore, orient='index', columns=['audience_tomato_score']).reset_index().rename(columns={'index': 'title'})

# %%
# Checking the dataframe of audience average rating, or "tom_df."
tom_df
# Out:
#                    title  audience_tomato_score
# 0                 Archer                     85
# 1   Arrested Development                     85
# 2          Bob's Burgers                     88
# 3        Bojack Horseman                     96
# 4           Breaking Bad                     97
# 5   Curb Your Enthusiasm                     90
# 6                  Fargo                     85
# 7       Freaks and Geeks                     96
# 8       General Hospital                      0
# 9    Halt and Catch Fire                      0
# 10              Seinfeld                     92
# 11       Stranger Things                     90

# %%
# Calling the MySQL view of internal ratings per series, segmented by reviewer and the series' average rating.
def call_reviews_metrics():
    
    conn = mysql.connector.connect( host="localhost", user="root", password="Jin$@otome90", database="tv_db")
    cur = conn.cursor(dictionary=True)

    # execute view
    cur.execute('SELECT * FROM series_ratings')

    # fetch all results or use fetchone()
    df_sql_data = pd.DataFrame(cur.fetchall())
        
    return df_sql_data
    conn.close() 
    cur.close()

# %%
# Calling the MySQL view into a dataframe variable "df."
df = call_reviews_metrics()

# %%
# Checking the "df" dataframe.
df
# Out:
#                    title  released_year      genre         reviewer rating  \
# 0                 Archer           2009  Animation  Thomas Stoneman    8.0
# 1                 Archer           2009  Animation     Wyatt Skaggs    7.5
# 2                 Archer           2009  Animation   Kimbra Masters    8.5
# 3                 Archer           2009  Animation   Domingo Cortes    7.7
# 4                 Archer           2009  Animation      Colt Steele    8.9
# 5   Arrested Development           2003     Comedy  Thomas Stoneman    8.1
# 6   Arrested Development           2003     Comedy   Domingo Cortes    6.0
# 7   Arrested Development           2003     Comedy   Kimbra Masters    8.0
# 8   Arrested Development           2003     Comedy     Pinkie Petit    8.4
# 9   Arrested Development           2003     Comedy      Colt Steele    9.9
# 10         Bob's Burgers           2011  Animation  Thomas Stoneman    7.0
# 11         Bob's Burgers           2011  Animation     Pinkie Petit    7.5
# 12         Bob's Burgers           2011  Animation   Domingo Cortes    8.0
# 13         Bob's Burgers           2011  Animation   Kimbra Masters    7.1
# 14         Bob's Burgers           2011  Animation      Colt Steele    8.0
# 15       Bojack Horseman           2014  Animation  Thomas Stoneman    7.5
# 16       Bojack Horseman           2014  Animation   Kimbra Masters    7.8
# 17       Bojack Horseman           2014  Animation   Domingo Cortes    8.3
# 18       Bojack Horseman           2014  Animation     Wyatt Skaggs    7.6
# 19       Bojack Horseman           2014  Animation      Colt Steele    8.5
# 20          Breaking Bad           2008      Drama  Thomas Stoneman    9.5
# 21          Breaking Bad           2008      Drama   Kimbra Masters    9.0
# 22          Breaking Bad           2008      Drama   Domingo Cortes    9.1
# 23          Breaking Bad           2008      Drama     Wyatt Skaggs    9.3
# 24          Breaking Bad           2008      Drama      Colt Steele    9.9
# 25  Curb Your Enthusiasm           2000     Comedy     Wyatt Skaggs    6.5
# 26  Curb Your Enthusiasm           2000     Comedy   Kimbra Masters    7.8
# 27  Curb Your Enthusiasm           2000     Comedy   Domingo Cortes    8.8
# 28  Curb Your Enthusiasm           2000     Comedy     Wyatt Skaggs    8.4
# 29  Curb Your Enthusiasm           2000     Comedy      Colt Steele    9.1
# 30                 Fargo           2014      Drama     Wyatt Skaggs    9.1
# 31                 Fargo           2014      Drama      Colt Steele    9.7
# 32      Freaks and Geeks           1999     Comedy   Domingo Cortes    8.5
# 33      Freaks and Geeks           1999     Comedy     Wyatt Skaggs    7.8
# 34      Freaks and Geeks           1999     Comedy     Pinkie Petit    8.8
# 35      Freaks and Geeks           1999     Comedy      Colt Steele    9.3
# 36      General Hospital           1963      Drama     Wyatt Skaggs    5.5
# 37      General Hospital           1963      Drama   Kimbra Masters    6.8
# 38      General Hospital           1963      Drama   Domingo Cortes    5.8
# 39      General Hospital           1963      Drama     Pinkie Petit    4.3
# 40      General Hospital           1963      Drama      Colt Steele    4.5
# 41   Halt and Catch Fire           2014      Drama      Colt Steele    9.9
# 42              Seinfeld           1989     Comedy   Kimbra Masters    8.0
# 43              Seinfeld           1989     Comedy   Domingo Cortes    7.2
# 44       Stranger Things           2016      Drama     Wyatt Skaggs    8.5
# 45       Stranger Things           2016      Drama   Kimbra Masters    8.9
# 46       Stranger Things           2016      Drama   Domingo Cortes    8.9
#
#    avg_series_rating
# 0                8.1
# 1                8.1
# 2                8.1
# 3                8.1
# 4                8.1
# 5                8.1
# 6                8.1
# 7                8.1
# 8                8.1
# 9                8.1
# 10               7.5
# 11               7.5
# 12               7.5
# 13               7.5
# 14               7.5
# 15               7.9
# 16               7.9
# 17               7.9
# 18               7.9
# 19               7.9
# 20               9.4
# 21               9.4
# 22               9.4
# 23               9.4
# 24               9.4
# 25               8.1
# 26               8.1
# 27               8.1
# 28               8.1
# 29               8.1
# 30               9.4
# 31               9.4
# 32               8.6
# 33               8.6
# 34               8.6
# 35               8.6
# 36               5.4
# 37               5.4
# 38               5.4
# 39               5.4
# 40               5.4
# 41               9.9
# 42               7.6
# 43               7.6
# 44               8.8
# 45               8.8
# 46               8.8

# %%
# Merging the MySQL dataframe list of all internal ratings with the audience average series' ratings.
#Let's call this master dataframe "fin_df."
fin_df = pd.merge(df, tom_df, on="title")

# %%
# Adding an index to the internal ratings vs audience ratings' dataframe, "fin_df," to circumvent the Python default "0."
fin_df.index+=1

# %%
# Knowing that "fin_df" refers to the final internal ratings vs audience ratings' dataframe.
fin_df
# Out:
#                    title  released_year      genre         reviewer rating  \
# 1                 Archer           2009  Animation  Thomas Stoneman    8.0
# 2                 Archer           2009  Animation     Wyatt Skaggs    7.5
# 3                 Archer           2009  Animation   Kimbra Masters    8.5
# 4                 Archer           2009  Animation   Domingo Cortes    7.7
# 5                 Archer           2009  Animation      Colt Steele    8.9
# 6   Arrested Development           2003     Comedy  Thomas Stoneman    8.1
# 7   Arrested Development           2003     Comedy   Domingo Cortes    6.0
# 8   Arrested Development           2003     Comedy   Kimbra Masters    8.0
# 9   Arrested Development           2003     Comedy     Pinkie Petit    8.4
# 10  Arrested Development           2003     Comedy      Colt Steele    9.9
# 11         Bob's Burgers           2011  Animation  Thomas Stoneman    7.0
# 12         Bob's Burgers           2011  Animation     Pinkie Petit    7.5
# 13         Bob's Burgers           2011  Animation   Domingo Cortes    8.0
# 14         Bob's Burgers           2011  Animation   Kimbra Masters    7.1
# 15         Bob's Burgers           2011  Animation      Colt Steele    8.0
# 16       Bojack Horseman           2014  Animation  Thomas Stoneman    7.5
# 17       Bojack Horseman           2014  Animation   Kimbra Masters    7.8
# 18       Bojack Horseman           2014  Animation   Domingo Cortes    8.3
# 19       Bojack Horseman           2014  Animation     Wyatt Skaggs    7.6
# 20       Bojack Horseman           2014  Animation      Colt Steele    8.5
# 21          Breaking Bad           2008      Drama  Thomas Stoneman    9.5
# 22          Breaking Bad           2008      Drama   Kimbra Masters    9.0
# 23          Breaking Bad           2008      Drama   Domingo Cortes    9.1
# 24          Breaking Bad           2008      Drama     Wyatt Skaggs    9.3
# 25          Breaking Bad           2008      Drama      Colt Steele    9.9
# 26  Curb Your Enthusiasm           2000     Comedy     Wyatt Skaggs    6.5
# 27  Curb Your Enthusiasm           2000     Comedy   Kimbra Masters    7.8
# 28  Curb Your Enthusiasm           2000     Comedy   Domingo Cortes    8.8
# 29  Curb Your Enthusiasm           2000     Comedy     Wyatt Skaggs    8.4
# 30  Curb Your Enthusiasm           2000     Comedy      Colt Steele    9.1
# 31                 Fargo           2014      Drama     Wyatt Skaggs    9.1
# 32                 Fargo           2014      Drama      Colt Steele    9.7
# 33      Freaks and Geeks           1999     Comedy   Domingo Cortes    8.5
# 34      Freaks and Geeks           1999     Comedy     Wyatt Skaggs    7.8
# 35      Freaks and Geeks           1999     Comedy     Pinkie Petit    8.8
# 36      Freaks and Geeks           1999     Comedy      Colt Steele    9.3
# 37      General Hospital           1963      Drama     Wyatt Skaggs    5.5
# 38      General Hospital           1963      Drama   Kimbra Masters    6.8
# 39      General Hospital           1963      Drama   Domingo Cortes    5.8
# 40      General Hospital           1963      Drama     Pinkie Petit    4.3
# 41      General Hospital           1963      Drama      Colt Steele    4.5
# 42   Halt and Catch Fire           2014      Drama      Colt Steele    9.9
# 43              Seinfeld           1989     Comedy   Kimbra Masters    8.0
# 44              Seinfeld           1989     Comedy   Domingo Cortes    7.2
# 45       Stranger Things           2016      Drama     Wyatt Skaggs    8.5
# 46       Stranger Things           2016      Drama   Kimbra Masters    8.9
# 47       Stranger Things           2016      Drama   Domingo Cortes    8.9
#
#    avg_series_rating  audience_tomato_score
# 1                8.1                     85
# 2                8.1                     85
# 3                8.1                     85
# 4                8.1                     85
# 5                8.1                     85
# 6                8.1                     85
# 7                8.1                     85
# 8                8.1                     85
# 9                8.1                     85
# 10               8.1                     85
# 11               7.5                     88
# 12               7.5                     88
# 13               7.5                     88
# 14               7.5                     88
# 15               7.5                     88
# 16               7.9                     96
# 17               7.9                     96
# 18               7.9                     96
# 19               7.9                     96
# 20               7.9                     96
# 21               9.4                     97
# 22               9.4                     97
# 23               9.4                     97
# 24               9.4                     97
# 25               9.4                     97
# 26               8.1                     90
# 27               8.1                     90
# 28               8.1                     90
# 29               8.1                     90
# 30               8.1                     90
# 31               9.4                     85
# 32               9.4                     85
# 33               8.6                     96
# 34               8.6                     96
# 35               8.6                     96
# 36               8.6                     96
# 37               5.4                      0
# 38               5.4                      0
# 39               5.4                      0
# 40               5.4                      0
# 41               5.4                      0
# 42               9.9                      0
# 43               7.6                     92
# 44               7.6                     92
# 45               8.8                     90
# 46               8.8                     90
# 47               8.8                     90

# %%
# Almost done! Let's standardize the final dataframe, or "fin_df," by dividing the audience_tomato_score by 10!
fin_df["audience_tomato_score"]=fin_df["audience_tomato_score"]/10

# %%
# We are all set with our dataframe and can commence the dashboarding building in Tableau!
fin_df
# Out:
#                    title  released_year      genre         reviewer rating  \
# 1                 Archer           2009  Animation  Thomas Stoneman    8.0
# 2                 Archer           2009  Animation     Wyatt Skaggs    7.5
# 3                 Archer           2009  Animation   Kimbra Masters    8.5
# 4                 Archer           2009  Animation   Domingo Cortes    7.7
# 5                 Archer           2009  Animation      Colt Steele    8.9
# 6   Arrested Development           2003     Comedy  Thomas Stoneman    8.1
# 7   Arrested Development           2003     Comedy   Domingo Cortes    6.0
# 8   Arrested Development           2003     Comedy   Kimbra Masters    8.0
# 9   Arrested Development           2003     Comedy     Pinkie Petit    8.4
# 10  Arrested Development           2003     Comedy      Colt Steele    9.9
# 11         Bob's Burgers           2011  Animation  Thomas Stoneman    7.0
# 12         Bob's Burgers           2011  Animation     Pinkie Petit    7.5
# 13         Bob's Burgers           2011  Animation   Domingo Cortes    8.0
# 14         Bob's Burgers           2011  Animation   Kimbra Masters    7.1
# 15         Bob's Burgers           2011  Animation      Colt Steele    8.0
# 16       Bojack Horseman           2014  Animation  Thomas Stoneman    7.5
# 17       Bojack Horseman           2014  Animation   Kimbra Masters    7.8
# 18       Bojack Horseman           2014  Animation   Domingo Cortes    8.3
# 19       Bojack Horseman           2014  Animation     Wyatt Skaggs    7.6
# 20       Bojack Horseman           2014  Animation      Colt Steele    8.5
# 21          Breaking Bad           2008      Drama  Thomas Stoneman    9.5
# 22          Breaking Bad           2008      Drama   Kimbra Masters    9.0
# 23          Breaking Bad           2008      Drama   Domingo Cortes    9.1
# 24          Breaking Bad           2008      Drama     Wyatt Skaggs    9.3
# 25          Breaking Bad           2008      Drama      Colt Steele    9.9
# 26  Curb Your Enthusiasm           2000     Comedy     Wyatt Skaggs    6.5
# 27  Curb Your Enthusiasm           2000     Comedy   Kimbra Masters    7.8
# 28  Curb Your Enthusiasm           2000     Comedy   Domingo Cortes    8.8
# 29  Curb Your Enthusiasm           2000     Comedy     Wyatt Skaggs    8.4
# 30  Curb Your Enthusiasm           2000     Comedy      Colt Steele    9.1
# 31                 Fargo           2014      Drama     Wyatt Skaggs    9.1
# 32                 Fargo           2014      Drama      Colt Steele    9.7
# 33      Freaks and Geeks           1999     Comedy   Domingo Cortes    8.5
# 34      Freaks and Geeks           1999     Comedy     Wyatt Skaggs    7.8
# 35      Freaks and Geeks           1999     Comedy     Pinkie Petit    8.8
# 36      Freaks and Geeks           1999     Comedy      Colt Steele    9.3
# 37      General Hospital           1963      Drama     Wyatt Skaggs    5.5
# 38      General Hospital           1963      Drama   Kimbra Masters    6.8
# 39      General Hospital           1963      Drama   Domingo Cortes    5.8
# 40      General Hospital           1963      Drama     Pinkie Petit    4.3
# 41      General Hospital           1963      Drama      Colt Steele    4.5
# 42   Halt and Catch Fire           2014      Drama      Colt Steele    9.9
# 43              Seinfeld           1989     Comedy   Kimbra Masters    8.0
# 44              Seinfeld           1989     Comedy   Domingo Cortes    7.2
# 45       Stranger Things           2016      Drama     Wyatt Skaggs    8.5
# 46       Stranger Things           2016      Drama   Kimbra Masters    8.9
# 47       Stranger Things           2016      Drama   Domingo Cortes    8.9
#
#    avg_series_rating  audience_tomato_score
# 1                8.1                    8.5
# 2                8.1                    8.5
# 3                8.1                    8.5
# 4                8.1                    8.5
# 5                8.1                    8.5
# 6                8.1                    8.5
# 7                8.1                    8.5
# 8                8.1                    8.5
# 9                8.1                    8.5
# 10               8.1                    8.5
# 11               7.5                    8.8
# 12               7.5                    8.8
# 13               7.5                    8.8
# 14               7.5                    8.8
# 15               7.5                    8.8
# 16               7.9                    9.6
# 17               7.9                    9.6
# 18               7.9                    9.6
# 19               7.9                    9.6
# 20               7.9                    9.6
# 21               9.4                    9.7
# 22               9.4                    9.7
# 23               9.4                    9.7
# 24               9.4                    9.7
# 25               9.4                    9.7
# 26               8.1                    9.0
# 27               8.1                    9.0
# 28               8.1                    9.0
# 29               8.1                    9.0
# 30               8.1                    9.0
# 31               9.4                    8.5
# 32               9.4                    8.5
# 33               8.6                    9.6
# 34               8.6                    9.6
# 35               8.6                    9.6
# 36               8.6                    9.6
# 37               5.4                    0.0
# 38               5.4                    0.0
# 39               5.4                    0.0
# 40               5.4                    0.0
# 41               5.4                    0.0
# 42               9.9                    0.0
# 43               7.6                    9.2
# 44               7.6                    9.2
# 45               8.8                    9.0
# 46               8.8                    9.0
# 47               8.8                    9.0

# %%
# Let's save the final dataframe to an Excel file named "Ratings_2024_xlsx."
# We are done!
fin_df.to_excel("Ratings_2024.xlsx", sheet_name="Sheet1")

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\rmmas'

# %%
#Checking to see if genre ratings'--for internal reviewers--match the Tableau LOD Calculation. They match!
# This, along with series of following steps, is established to check for data quality and single source of truth.
round(fin_df.groupby("genre")["rating"].mean(),1)
# Out:
# genre
# Animation    7.9
# Comedy       8.2
# Drama        8.0
# Name: rating, dtype: float64

# %%
# Ensuring MySQL result matched the avg series' ratings--for internal reviewers--with Tableau Dashboard.
# They do match indeed! 
round(fin_df.groupby("title")["rating"].mean(),1)
# Out:
# title
# Archer                  8.1
# Arrested Development    8.1
# Bob's Burgers           7.5
# Bojack Horseman         7.9
# Breaking Bad            9.4
# Curb Your Enthusiasm    8.1
# Fargo                   9.4
# Freaks and Geeks        8.6
# General Hospital        5.4
# Halt and Catch Fire     9.9
# Seinfeld                7.6
# Stranger Things         8.8
# Name: rating, dtype: float64

# %%
# EDA for released year average internal rating.
round(fin_df.groupby("released_year")["rating"].mean(),1)
# Out:
# released_year
# 1963    5.4
# 1989    7.6
# 1999    8.6
# 2000    8.1
# 2003    8.1
# 2008    9.4
# 2009    8.1
# 2011    7.5
# 2014    8.6
# 2016    8.8
# Name: rating, dtype: float64

# %%
# Checking to see if results match Tableau Dashboard.
# They match!
round(fin_df[fin_df["reviewer"]=="Colt Steele"].groupby("genre")["rating"].mean(),1)
# Out:
# genre
# Animation    8.5
# Comedy       9.4
# Drama        8.5
# Name: rating, dtype: float64

# %%
# Checking to see if results match Tableau Dashboard.
# They match! 
round(fin_df[fin_df["reviewer"]=="Thomas Stoneman"].groupby("genre")["rating"].mean(),1)
# Out:
# genre
# Animation    7.5
# Comedy       8.1
# Drama        9.5
# Name: rating, dtype: float64

# %%
print("Hello")
# Out:
# Hello
